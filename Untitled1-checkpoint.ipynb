# %%
# !pip install scikit-learn

# %%
import sklearn as sk

# %%
# !pip install statsmodels

# %%
import statsmodels.formula.api as smf

# %%
import statsmodels.formula.api as smf
dir(smf)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'conditional_logit',
#  'conditional_mnlogit',
#  'conditional_poisson',
#  'gee',
#  'glm',
#  'glmgam',
#  'gls',
#  'glsar',
#  'logit',
#  'mixedlm',
#  'mnlogit',
#  'negativebinomial',
#  'nominal_gee',
#  'ols',
#  'ordinal_gee',
#  'phreg',
#  'poisson',
#  'probit',
#  'quantreg',
#  'rlm',
#  'wls']

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
df = pd.read_parquet('teca.parquet')

# %%
import pandas as pd

df = pd.read_parquet("teca.parquet")

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050000 entries, 0 to 1049999
# Data columns (total 24 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   unique_id         1050000 non-null  int64
#  1   transaction_id    1050000 non-null  object
#  2   unformatted_date  1050000 non-null  datetime64[ns]
#  3   customer_id       1050000 non-null  object
#  4   product_id        1050000 non-null  object
#  5   product_name      1050000 non-null  object
#  6   category_id       1050000 non-null  int64
#  7   category_name     1050000 non-null  object
#  8   parent_id         1050000 non-null  int64
#  9   parent_name       1050000 non-null  object
#  10  product_count     1050000 non-null  int64
#  11  site_id           1050000 non-null  object
#  12  site_name         1050000 non-null  object
#  13  address           1050000 non-null  object
#  14  city              1050000 non-null  object
# ...

# %%
import pandas as pd

df = pd.read_parquet("teca.parquet")

df.info()
df.head()
df.columns.tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050000 entries, 0 to 1049999
# Data columns (total 24 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   unique_id         1050000 non-null  int64
#  1   transaction_id    1050000 non-null  object
#  2   unformatted_date  1050000 non-null  datetime64[ns]
#  3   customer_id       1050000 non-null  object
#  4   product_id        1050000 non-null  object
#  5   product_name      1050000 non-null  object
#  6   category_id       1050000 non-null  int64
#  7   category_name     1050000 non-null  object
#  8   parent_id         1050000 non-null  int64
#  9   parent_name       1050000 non-null  object
#  10  product_count     1050000 non-null  int64
#  11  site_id           1050000 non-null  object
#  12  site_name         1050000 non-null  object
#  13  address           1050000 non-null  object
#  14  city              1050000 non-null  object
# ...

# %%
df.info()
df.head()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050000 entries, 0 to 1049999
# Data columns (total 24 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   unique_id         1050000 non-null  int64
#  1   transaction_id    1050000 non-null  object
#  2   unformatted_date  1050000 non-null  datetime64[ns]
#  3   customer_id       1050000 non-null  object
#  4   product_id        1050000 non-null  object
#  5   product_name      1050000 non-null  object
#  6   category_id       1050000 non-null  int64
#  7   category_name     1050000 non-null  object
#  8   parent_id         1050000 non-null  int64
#  9   parent_name       1050000 non-null  object
#  10  product_count     1050000 non-null  int64
#  11  site_id           1050000 non-null  object
#  12  site_name         1050000 non-null  object
#  13  address           1050000 non-null  object
#  14  city              1050000 non-null  object
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# units               61003
# gp_margin           21599
# costs               21599
# gross_profit        21599
# transaction_id          0
# revenue                 0
# site_status             0
# longitude               0
# latitude                0
# zip                     0
# city                    0
# address                 0
# unique_id               0
# site_id                 0
# product_count           0
# parent_name             0
# parent_id               0
# category_name           0
# category_id             0
# product_name            0
# product_id              0
# customer_id             0
# unformatted_date        0
# site_name               0
# dtype: int64

# %%
df[['revenue', 'costs', 'gross_profit', 'gp_margin']].describe()
# Out:
#             revenue         costs  gross_profit     gp_margin
# count  1.050000e+06  1.028401e+06  1.028401e+06  1.028401e+06
# mean   4.060675e+01  6.416577e+00  1.692989e+00 -4.155474e-01
# std    7.383941e+03  1.496193e+01  4.760644e+00  1.317233e+01
# min   -1.680000e+03 -4.756100e+02 -1.693200e+02 -2.859000e+03
# 25%    1.490000e+00  6.898620e-01  6.390000e-01  1.276940e-01
# 50%    2.490000e+00  1.286110e+00  1.055100e+00  3.485680e-01
# 75%    6.510000e+00  5.218640e+00  1.840000e+00  5.416852e-01
# max    4.500000e+06  9.490500e+02  5.000000e+02  5.263900e+01

# %%
df['category_name'].value_counts().head(10)
df['site_name'].value_counts().head(10)
df['city'].value_counts().head(10)
# Out:
# city
# Columbia         28359
# Aurora           23678
# Rogers           16854
# Commerce City    15062
# Gardendale       13729
# Mobile           12818
# Alamosa          12033
# Henderson        11913
# Hitchcock        11111
# Hamilton         10642
# Name: count, dtype: int64
